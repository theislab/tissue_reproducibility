# %%
# %load_ext autoreload
# %autoreload 2

# %%
import anndata
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import scanpy as sc
import seaborn as sns

import tissue.api as tissue
# Out:
# /home/icb/sabrina.richter/miniconda3/envs/tissue/lib/python3.8/site-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.7) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
ls /mnt/home/icb/sabrina.richter/git/testruns/grid_searches/210527_GCN_SPECTRAL_GROUP_TYPE_schuerch_RADIUS_MULTITASK/results
# Out:
# checkpoint
# gcn_spectral_schuerch_Groupadam_lr2_dr1_drp1_l21_de2_wi2_lw1_lt1_bs2_md1_tk1_ck1_fstype_fe1_fpmean_mttarget_nc1_ew1_nh1_ssmultitask_cv0_evaluation.pickle
# gcn_spectral_schuerch_Groupadam_lr2_dr1_drp1_l21_de2_wi2_lw1_lt1_bs2_md1_tk1_ck1_fstype_fe1_fpmean_mttarget_nc1_ew1_nh1_ssmultitask_cv0_get_data_args.pickle
# gcn_spectral_schuerch_Groupadam_lr2_dr1_drp1_l21_de2_wi2_lw1_lt1_bs2_md1_tk1_ck1_fstype_fe1_fpmean_mttarget_nc1_ew1_nh1_ssmultitask_cv0_history.pickle
# gcn_spectral_schuerch_Groupadam_lr2_dr1_drp1_l21_de2_wi2_lw1_lt1_bs2_md1_tk1_ck1_fstype_fe1_fpmean_mttarget_nc1_ew1_nh1_ssmultitask_cv0_hyperparam.pickle
# gcn_spectral_schuerch_Groupadam_lr2_dr1_drp1_l21_de2_wi2_lw1_lt1_bs2_md1_tk1_ck1_fstype_fe1_fpmean_mttarget_nc1_ew1_nh1_ssmultitask_cv0_model_args.pickle
# gcn_spectral_schuerch_Groupadam_lr2_dr1_drp1_l21_de2_wi2_lw1_lt1_bs2_md1_tk1_ck1_fstype_fe1_fpmean_mttarget_nc1_ew1_nh1_ssmultitask_cv0_model_weights.tf.data-00000-of-00001
# ...

# %%
results_path = '/mnt/home/icb/sabrina.richter/git/testruns/grid_searches/'
gs_ids = ['210527_GCN_SPECTRAL_GROUP_TYPE_schuerch_RADIUS_MULTITASK']

gs_container = tissue.fits.GridSearchContainer(
    source_path=results_path,
    gs_ids=gs_ids,
)

gs_container.load_gs()
# Out:
# loaded 210527_GCN_SPECTRAL_GROUP_TYPE_schuerch_RADIUS_MULTITASK: 8 runs with 6-fold cross validation

# %%
gs_container.summary_table
# Out:
#       activation aggregation batch_size covariate_selection  \
# 0  leakyrelu_0.1    spectral         32             n_o_n_e
# 1  leakyrelu_0.1    spectral         32             n_o_n_e
# 2  leakyrelu_0.1    spectral         32             n_o_n_e
# 3  leakyrelu_0.1    spectral         32             n_o_n_e
# 4  leakyrelu_0.1    spectral         32             n_o_n_e
# 5  leakyrelu_0.1    spectral         32             n_o_n_e
# 6  leakyrelu_0.1    spectral         32             n_o_n_e
# 7  leakyrelu_0.1    spectral         32             n_o_n_e
# 0  leakyrelu_0.1    spectral         32             n_o_n_e
# 1  leakyrelu_0.1    spectral         32             n_o_n_e
# 2  leakyrelu_0.1    spectral         32             n_o_n_e
# 3  leakyrelu_0.1    spectral         32             n_o_n_e
# 4  leakyrelu_0.1    spectral         32             n_o_n_e
# 5  leakyrelu_0.1    spectral         32             n_o_n_e
# 6  leakyrelu_0.1    spectral         32             n_o_n_e
# ...
